# %% [markdown]
# # Amat Samuel

# %% [markdown]
# # Espacios invariantes para ecuaciones lineales

# %% [markdown]
# Consideremos de nuevo la ecuación lineal
#
# $$\dot{\mathbf{x}} = \mathsf{A} \cdot \mathbf{x}$$
#
# Como hemos visto, los eigenvectores de $\mathsf{A}$ juegan un papel importante.

# %% [markdown]
# **[1]** (i) Dibuja el espacio fase del sistema $$\dot{\mathbf{x}} = \mathsf{A} \cdot \mathbf{x}$$ con
# $$A = \begin{pmatrix} 1 & 1 \\ 4 & -2 \end{pmatrix}. $$
#
# (ii) Agrega el punto fijo.
#
# (iii) Calcula los eigenvectores y eigenvalores de $\mathsf{A}$.
#
# (iv) Dibuja los eigenvectores encima de la gráfica del inciso (i). ¿Qué observas? ¿Qué concluyes?

# %% [markdown]
# ### Solución

# %% [markdown]
# la ecuación diferencial anterior corresponde al siguiente sistema de ecuaciones:
# \begin{eqnarray}
# \dot{x} = x + y \\
# \dot{y} = 4x - 2y
# \end{eqnarray}
# A continuación se muestra el campo vectorial asociado al sistema de ecs. de arriba, i.e el espacio fase.

# %%
using DifferentialEquations
using Plots
using ForwardDiff
gr()
include("funciones_especiales.jl")
# Out:
# estabilidad_nolineal2D (generic function with 1 method)

# %%
#sistema de ecs. diferenciales no-lineales
function RHS1(du::Array{Float64,1}, u::Array{Float64,1}, p::Void, t::Float64)
        du[1] = u[1] + u[2]
        du[2] = 4u[1] - 2u[2]
end
#jacobiano
A1(u) = [1. 1.; 4. -2.]
# Out:
# A1 (generic function with 1 method)

# %%
X = linspace(-100, 100, 10)
Y = linspace(-100, 100, 10)
xlim = (-100., 100.)
ylim = (-100., 100.)
tmax = 1.
h = 0.01
k = 10.
plot(xlims=xlim, ylims=ylim)
estabilidad_nolineal2D(RHS1, A1, X, Y, k, tmax, h)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="700" height="400" viewBox="0 0 700 400">
# <defs>
#   <clipPath id="clip8100">
#     <rect x="0" y="0" width="700" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip8100)" points="
# 0,400 700,400 700,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip8101">
#     <rect x="140" y="0" width="491" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip8100)" points="
# 58.5953,360.121 680.315,360.121 680.315,11.811 58.5953,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip8102">
#     <rect x="58" y="11" width="623" height="349"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip8102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   58.5953,360.121 58.5953,11.811
#   "/>
# <polyline clip-path="url(#clip8102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   214.025,360.121 214.025,11.811
#   "/>
# <polyline clip-path="url(#clip8102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   369.455,360.121 369.455,11.811
#   "/>
# <polyline clip-path="url(#clip8102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   524.885,360.121 524.885,11.811
#   "/>
# <polyline clip-path="url(#clip8102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   680.315,360.121 680.315,11.811
#   "/>
# <polyline clip-path="url(#clip8102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   58.5953,360.121 680.315,360.121
#   "/>
# <polyline clip-path="url(#clip8102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   58.5953,273.043 680.315,273.043
#   "/>
# <polyline clip-path="url(#clip8102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   58.5953,185.966 680.315,185.966
#   "/>
# <polyline clip-path="url(#clip8102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   58.5953,98.8884 680.315,98.8884
#   "/>
# <polyline clip-path="url(#clip8102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   58.5953,11.811 680.315,11.811
#   "/>
# <polyline clip-path="url(#clip8100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   58.5953,360.121 680.315,360.121
#   "/>
# <polyline clip-path="url(#clip8100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   58.5953,360.121 58.5953,11.811
#   "/>
# <polyline clip-path="url(#clip8100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   58.5953,360.121 58.5953,354.896
#   "/>
# <polyline clip-path="url(#clip8100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   214.025,360.121 214.025,354.896
#   "/>
# <polyline clip-path="url(#clip8100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   369.455,360.121 369.455,354.896
#   "/>
# <polyline clip-path="url(#clip8100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   524.885,360.121 524.885,354.896
#   "/>
# <polyline clip-path="url(#clip8100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   680.315,360.121 680.315,354.896
#   "/>
# <polyline clip-path="url(#clip8100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   58.5953,360.121 67.9211,360.121
#   "/>
# <polyline clip-path="url(#clip8100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   58.5953,273.043 67.9211,273.043
#   "/>
# <polyline clip-path="url(#clip8100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   58.5953,185.966 67.9211,185.966
#   "/>
# <polyline clip-path="url(#clip8100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   58.5953,98.8884 67.9211,98.8884
#   "/>
# <polyline clip-path="url(#clip8100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   58.5953,11.811 67.9211,11.811
#   "/>
# <g clip-path="url(#clip8100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 58.5953, 374.421)" x="58.5953" y="374.421">-100</text>
# </g>
# <g clip-path="url(#clip8100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 214.025, 374.421)" x="214.025" y="374.421">-50</text>
# </g>
# <g clip-path="url(#clip8100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 369.455, 374.421)" x="369.455" y="374.421">0</text>
# </g>
# <g clip-path="url(#clip8100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 524.885, 374.421)" x="524.885" y="374.421">50</text>
# </g>
# <g clip-path="url(#clip8100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 680.315, 374.421)" x="680.315" y="374.421">100</text>
# </g>
# <g clip-path="url(#clip8100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 51.5953, 364.621)" x="51.5953" y="364.621">-100</text>
# </g>
# <g clip-path="url(#clip8100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 51.5953, 277.543)" x="51.5953" y="277.543">-50</text>
# </g>
# <g clip-path="url(#clip8100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 51.5953, 190.466)" x="51.5953" y="190.466">0</text>
# </g>
# <g clip-path="url(#clip8100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 51.5953, 103.388)" x="51.5953" y="103.388">50</text>
# </g>
# <g clip-path="url(#clip8100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 51.5953, 16.311)" x="51.5953" y="16.311">100</text>
# </g>
# <g clip-path="url(#clip8100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 369.455, 397.6)" x="369.455" y="397.6">dx/dt</text>
# </g>
# <g clip-path="url(#clip8100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(-90, 14.4, 185.966)" x="14.4" y="185.966">dy/dt</text>
# </g>
# <polyline clip-path="url(#clip8102)" style="stroke:#009af9; stroke-width:2; stroke-opacity:1; fill:none" points="
#   58.5953,360.121 52.3156,363.639 45.9089,367.228 39.3728,370.89 32.7047,374.625 25.9019,378.437 18.9617,382.325 11.8813,386.292 4.65778,390.338 -2.71163,394.467
#   -10.2299,398.679 -17.9001,402.976 -25.7252,407.36 -33.7083,411.832 -41.8527,416.395 -50.1617,421.05 -58.6385,425.799 -67.2865,430.644 -76.1093,435.587 -85.1103,440.63
#   -94.2932,445.774 -103.662,451.023 -113.219,456.377 -122.97,461.84 -132.918,467.413 -143.066,473.099 -153.42,478.899 -163.983,484.817 -174.759,490.854 -185.752,497.013
#   -196.968,503.297 -208.411,509.707 -220.084,516.247 -231.994,522.919 -244.144,529.726 -256.539,536.67 -269.185,543.755 -282.087,550.983 -295.249,558.357 -308.677,565.88
#   -322.376,573.555 -336.352,581.384 -350.611,589.372 -365.157,597.522 -379.997,605.836 -395.137,614.318 -410.583,622.971 -426.

# %% [markdown]
# #### Los vectores propios separan el comportamiento del campo en regiones distintas. En general se observa que los vectores propios se comportan como espacios vectoriales desde donde divergen y a donde convergen las soluciones

# %% [markdown]
# Lo que acabas de calcular son los **espacios invariantes** del sistema dinámico descrito por la ecuación diferencial:
#
# - el **espacio estable** consiste en el span de los eigenvectores cuyos eigenvalores corresponden a las "direcciones estables", es decir aquellas con parte real negativa;
#
# - el **espacio inestable**, correspondiente a la parte real positiva.

# %% [markdown]
# **[2]** (i) Considera una trayectoria que empieza encima del espacio estable. ¿Qué ocurre? Hazlo numéricamente.
#
# (ii) Haz lo mismo para el espacio inestable.

# %% [markdown]
# ### Solución

# %%
tmax=1.
pto = [0.,0.]
A = A1(pto)
ux = [90.*eig(A)[2][1,1]]#, 90.*eig(A)[2][1,2]]
uy = [90.*eig(A)[2][2,1]]#, 90.*eig(A)[2][2,2]]
cond_init = [[ux[i], uy[j]] for i=1:length(ux), j=1:length(uy)]
solx=[]
soly=[]
for i in 1:length(cond_init)
    prob = ODEProblem(RHS1, cond_init[i], (0, tmax))
    sol = solve(prob, saveat=h)
    a = [sol.u[i][1] for i = 1:length(sol.u)]
    sols = hcat(a, [sol.u[i][2] for i =1:length(sol.u)])
    solx = sols[:,1]
    soly = sols[:,2]
end
scatter(solx, label="λ>0", color=:red, xlabel="tiempo", ylabel="coordenadas")
p1 = scatter!(soly, label="", color=:red, title="espacio inestable")

ux = [90.*eig(A)[2][1,2]]#, 90.*eig(A)[2][1,2]]
uy = [90.*eig(A)[2][2,2]]#, 90.*eig(A)[2][2,2]]
cond_init = [[ux[i], uy[j]] for i=1:length(ux), j=1:length(uy)]
solx=[]
soly=[]
for i in 1:length(cond_init)
    prob = ODEProblem(RHS1, cond_init[i], (0, tmax))
    sol = solve(prob, saveat=h)
    a = [sol.u[i][1] for i = 1:length(sol.u)]
    sols = hcat(a, [sol.u[i][2] for i =1:length(sol.u)])
    solx = sols[:,1]
    soly = sols[:,2]
end
scatter(solx, label="λ<0", xlabel="tiempo", ylabel="coordenadas", color=:blue)
p2 = scatter!(soly, label="", color=:blue, title="espacio estable")
plot(p1, p2)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="cl
# $$\dot{\mathbf{x}} = \mathbf{f}(\mathbf{x}).$$
#
# Si sabemos que tiene un punto fijo $\mathbf{x}^*$, podemos hacer el análisis de estabilidad lineal ahí, que hasta ahora nos ha servido para encontrar si es un punto fijo estable o inestable.
#
# Sin embargo, va más allá que eso: sea $\mathsf{J} := D\mathbf{f}(\mathbf{x}^*)$ la matrix jacobiana en el punto fijo. Entonces la ecuación
#
# $$\dot{\mathbf{x}} = \mathsf{J} \cdot \mathbf{x}$$
#
# se llama el **sistema linealizado** en el punto fijo.

# %% [markdown]
# **[3]** Considera de nuevo la ecuación
#
# \begin{align}
# \dot{x} &= x + \exp(-y)\\
# \dot{y} &= -y
# \end{align}
#
# (i) Dibuja el espacio fase del sistema nolineal, incluyendo el punto fijo.
#
# (ii) Encuentra el sistema linealizado en el punto fijo, y dibuja su espacio fase encima, cerca del punto fijo.
#
# (iii) Dibuja los espacios invariantes del sistema linealizado encima. ¿Qué observas?

# %% [markdown]
# ### Solución.

# %%
function RHS2(du::Array{Float64,1}, u::Array{Float64,1}, p::Void, t::Float64)
        du[1] = u[1] + exp(-u[2])
        du[2] = -u[2]
end
J2(u) = [1 -exp(-u[2]); 0 -1]
# Out:
# J2 (generic function with 1 method)

# %%
function RHS2_linealizado(du::Array{Float64,1}, u::Array{Float64,1}, p::Void, t::Float64)
        du[1] = (u[1] + 1.) - (u[2] - 0.)
        du[2] = -(u[2] - 0.)
end
# Out:
# RHS2_linealizado (generic function with 1 method)

# %%
X = linspace(-2.4, 0.6, 8)
Y = linspace(-1.4, 1.4, 8)
xlim = (-2.4, 0.6)
ylim = (-1.4, 1.4)
tmax = 4.
h = 0.1
k=4.
plot(xlims=xlim, ylims=ylim, title="linealizado")
p1 = estabilidad_nolineal2D(RHS2_linealizado, J2, X, Y, k, tmax, h)
plot(xlims=xlim, ylims=ylim, title="no lineal")
p2 = estabilidad_nolineal2D(RHS2, J2, X, Y, k, tmax, h)
plot(p1, p2)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="700" height="400" viewBox="0 0 700 400">
# <defs>
#   <clipPath id="clip8500">
#     <rect x="0" y="0" width="700" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip8500)" points="
# 0,400 700,400 700,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip8501">
#     <rect x="140" y="0" width="491" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip8500)" points="
# 55.25,360.121 330.315,360.121 330.315,31.4961 55.25,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip8502">
#     <rect x="55" y="31" width="276" height="330"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip8502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   91.9254,360.121 91.9254,31.4961
#   "/>
# <polyline clip-path="url(#clip8502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   137.77,360.121 137.77,31.4961
#   "/>
# <polyline clip-path="url(#clip8502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   183.614,360.121 183.614,31.4961
#   "/>
# <polyline clip-path="url(#clip8502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   229.458,360.121 229.458,31.4961
#   "/>
# <polyline clip-path="url(#clip8502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   275.302,360.121 275.302,31.4961
#   "/>
# <polyline clip-path="url(#clip8502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   321.146,360.121 321.146,31.4961
#   "/>
# <polyline clip-path="url(#clip8502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   55.25,313.174 330.315,313.174
#   "/>
# <polyline clip-path="url(#clip8502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   55.25,254.491 330.315,254.491
#   "/>
# <polyline clip-path="url(#clip8502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   55.25,195.808 330.315,195.808
#   "/>
# <polyline clip-path="url(#clip8502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   55.25,137.125 330.315,137.125
#   "/>
# <polyline clip-path="url(#clip8502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   55.25,78.4424 330.315,78.4424
#   "/>
# <polyline clip-path="url(#clip8500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   55.25,360.121 330.315,360.121
#   "/>
# <polyline clip-path="url(#clip8500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   55.25,360.121 55.25,31.4961
#   "/>
# <polyline clip-path="url(#clip8500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   91.9254,360.121 91.9254,355.191
#   "/>
# <polyline clip-path="url(#clip8500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   137.77,360.121 137.77,355.191
#   "/>
# <polyline clip-path="url(#clip8500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   183.614,360.121 183.614,355.191
#   "/>
# <polyline clip-path="url(#clip8500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   229.458,360.121 229.458,355.191
#   "/>
# <polyline clip-path="url(#clip8500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   275.302,360.121 275.302,355.191
#   "/>
# <polyline clip-path="url(#clip8500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   321.146,360.121 321.146,355.191
#   "/>
# <polyline clip-path="url(#clip8500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   55.25,313.174 59.376,313.174
#   "/>
# <polyline clip-path="url(#clip8500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   55.25,254.491 59.376,254.491
#   "/>
# <polyline clip-path="url(#clip8500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   55.25,195.808 59.376,195.808
#   "/>
# <polyline clip-path="url(#clip8500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   55.25,137.125 59.376,137.125
#   "/>
# <polyline clip-path="url(#clip8500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   55.25,78.4424 59.376,78.4424
#   "/>
# <g clip-path="url(#clip8500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 91.9254, 374.421)" x="91.9254" y="374.421">-2.0</text>
# </g>
# <g clip-path="url(#clip8500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 137.77, 374.421)" x="137.77" y="374.421">-1.5</text>
# </g>
# <g clip-path="url(#clip8500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 183.614, 374.421)" x="183.614" y="374.421">-1.0</text>
# </g>
# <g clip-path="url(#clip8500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 229.458, 374.421)" x="229.458" y="374.421">-0.5</text>
# </g>
# <g clip-path="url(#clip8500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 275.302, 374.421)" x="275.302" y="374.421">0.0</text>
# </g>
# <g clip-path="url(#clip8500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 321.146, 374.421)" x="321.146" y="374.421">0.5</text>
# </g>
# <g clip-path="url(#clip8500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 48.25, 317.674)" x="48.25" y="317.674">-1.0</text>
# </g>
# <g clip-path="url(#clip8500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 48.25, 258.991)" x="48.25" y="258.991">-0.5</text>
# </g>
# <g clip-path="url(#clip8500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 48.25, 200.308)" x="48.25" y="200.308">0.0</text>
# </g>
# <g clip-path="url(#clip8500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 48.25, 141.625)" x="48.25" y="141.625">0.5</text>
# </g>
# <g clip-path="url(#clip8500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 48.25, 82.9424)" x="48.25" y="82.9424">1.0</text>
# </g>
# <g clip-path="url(#clip8500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 192.783, 18)" x="192.783" y="18">linealizado</text>
# </g>
# <g clip-path="url(#clip8500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 192.783, 397.6)" x="192.783" y="397.6">dx/dt</text>
# </g>
# <g clip-path="url(#clip8500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(-90, 14.4, 195.808)" x="14.4" y="195.808">dy/dt</text>
# </g>
# <polyline clip-path="url(#clip8502)" style="stroke:#009af9; stroke-width:2; stroke-opacity:1; fill:none" points="
#   55.25,360.121 54.6077,344.484 52.67

# %% [markdown]
# #### Izquierda se muestra el sistema linealizado junto con los dos espacios invariantes dados por los generados de cada vector propio (i.e rectas punteadas).
# #### Derecha se muestra el sistema original (no lineal).
# #### Vemos que el cerca del punto fijo (haciendo un zoom con plotly) en el sistema no lineal los espacios invariantes parecen ser correctos, es decir, el sistema se aproxima y aleja respectivamente de c/u de ellos asintóticamente, pero al ver el sistema más de lejos vemos, que esto falla.
#
# #### NOTA: no encimé las gráficas como se pide porque no era claro el análisis por la confusión entre campos lineal y no lineal, espero se entienda

# %% [markdown]
# ## El teorema de Hartman&ndash;Grobman

# %% [markdown]
# Debes haber observado en el inciso [2] que el comportamiento de los sistemas nolineal y linealizado se parecen cerca del punto fijo.
#
# La idea es que cerca del punto fijo, el sistema nolineal se puede desarrollar:
#
# $$\dot{\mathbf{x}} = [D\mathbf{f}(\mathbf{x}^*)] \cdot \mathbf{x} + O(\mathbf{\delta x}^2),$$
#
# donde los términos nolineales son chiquitos.
# Por lo tanto, uno podría esperar que las dinámicas de los sistemas nolineales y linealizados fueran parecidas cerca del punto fijo, ya que ahí la diferencia en la dinámica es pequeña.
#
#
# El teorema de Hartman&ndash;Grobman hace rigurosaesta idea.
#
# La
#
# Primero, definimos un **punto fijo hiperbólico** $\mathbf{x}^*$ como un punto fijo tal que ningún eigenvalor de la matriz jacobiano en ese punto se encuentre en el eje imaginario.
#
# El teorema dice:
# > Si $\mathbf{x}^*$ es un punto fijo hiperbólico de la ecuación $\dot{\mathbf{x}} = \mathbf{f}(\mathbf{x})$, entonces cerca del punto fijo, el flujo de la ecuación nolineal "se parece" al flujo de la ecuación lineal.
#
# Aquí, "se parece" quiere decir que existe un homeomorfismo (función continua e invertible) que lleva órbitas del sistema lineal a órbitas del sistema nolineal.
#
# Nótese que en general esto ** *no* es cierto cuando el punto fijo es no-hiperbólico **.

# %% [markdown]
# ## Variedades invariantes

# %% [markdown]
# Dado el teorema de Hartman&ndash;Grobman, debe existir un análogo en el sistema nolineal de los espacios estable e inestable del sistema lineal. Estas curvas deben obtenerse al mapear las trayectorias correspondientes a estos espacios invariantes bajo el homeomorfismo.
#
# Estas curvas (o variedades, en general) son entonces "versiones curveadas" de los espacios invariantes.

# %% [markdown]
# **[4]**
#
# (i) ¿Cómo se pueden definir las variedades invariantes en términos de su comportamiento asintótico?
#
# (ii) Muy cerca del punto fijo, las variedades invariantes son casi idénticas a los espacios invariantes.
#
# Utiliza esta idea para calcular las variedades invariantes de la ecuación del inciso **[3]**.
#
# (iii) Dibuja las variedades invariantes y los espacios invariantes. ¿Qué observas?
#
# (iv) Dibuja el espacio fase completo del sistema nolineal.

# %% [markdown]
# ### Solución

# %% [markdown]
# #### Las variedades invariantes cumplen ser los espacios vectoriales desde los cuales las souciones tienden asintóticamente al punto fijo (estables) o se alejan de él (inestables).
# #### Utilizando la idea del teorema de HG, podemos colocarnos sobre el espacio invariante estable cerca del punto fijo y propagar una solución hacia atrás en el tiempo, eso construye la variedad estable. Análogamente, colocándonos en el espacio invariante inestable muy cerca del punto fijo, propagando hacia adelante en el tiempo podemos encontrar la variedad estable.

# %%
function variedades_invariantes(RHS, J, meshx, meshy, k, tmax, h)
    pts = PFs_estabilidad(RHS, J, meshx, meshy, "eigenvalor")
    pts_eig = PFs_estabilidad(RHS, J, meshx, meshy, "eigenvector")
    pts_hiperb = pts_eig["silla"] 
    v1 = pts_hiperb[1][:,1]
    λ1 = pts_hiperb[2][1]
    m1 = v1[2]/v1[1]
    v2 = pts_hiperb[1][:,2]
    λ2 = pts_hiperb[2][2]
    m2 = v2[2]/v2[1]
    v3 = pts["silla"][1]
    l1 = l2 = ""
    if λ1 < 0
        l1 = "espacio estable"
        l2 = "espacio inestable"
    else
        l1 = "espacio inestable"
        l2 = "espacio estable"
    end
    δx = 1e-4
    #variedades estables, se propaga a tiempos negativos
    ux = linspace(v3[1] + δx, v3[1] + δx, 1)
    uy = linspace(-m2*δx + v3[2], m2*δx + v3[2], 2)
    #for i in pts_eig["silla"]
     #   if pts_eig["silla"]
    cond_init = [[ux[i], uy[j]] for i=1:length(ux), j=1:length(uy)]
    for i in 1:length(cond_init)
        prob = ODEProblem(RHS, cond_init[i], (0., -2*tmax))
        sol = solve(prob, Tsit5())
        a = [sol.u[i][1] for i = 1:length(sol.u)]
        sols = hcat(a, [sol.u[i][2] for i =1:length(sol.u)])
        solx = sols[:,1]
        soly = sols[:,2]
        plot!(solx, soly, lw=2, linestyle=:dash, label="variedad estable", color=:blue)
    end
    #variedad inestable, se propaga a tiempos positivos
    ux = linspace(v3[1] + δx, v3[1] - δx, 2)
    uy = linspace(-m1*δx + v3[2], -m1*δx + v3[2], 1)
    cond_init = [[ux[i], uy[j]] for i=1:length(ux), j=1:length(uy)]
    for i in 1:length(cond_init)
        prob = ODEProblem(RHS, cond_init[i], (0., 2*tmax))
        sol = solve(prob, Tsit5())
        a = [sol.u[i][1] for i = 1:length(sol.u)]
        sols = hcat(a, [sol.u[i][2] for i =1:length(sol.u)])
        solx = sols[:,1]
        soly = sols[:,2]
        plot!(solx, soly, lw=2, linestyle=:dash, label="variedad inestable", color=:red)
    end
    
    campo(RHS, meshx, meshy, k, tmax, h)
    plot!(meshx, x->(m1*(x-v3[1])+v3[2]), label=l1, linestyle=:dash, lw=2)
    plot!(meshx, x->(m2*(x-v3[1])+v3[2]), label=l2, linestyle=:dash ,lw=2)
end
# Out:
# variedades_invariantes (generic function with 1 method)

# %%
X = linspace(-2., 0., 10)
Y = linspace(-1.0, 1.0, 10)
xlim = (-2., 0.)
ylim = (-1.0, 1.0)
tmax = 5.
h = 0.01
k=4.
plot(xlims=xlim, ylims=ylim)
variedades_invariantes(RHS2, J2, X, Y, k, tmax, h)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="cl